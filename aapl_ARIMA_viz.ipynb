# %%
import pandas as pd

# %%
### 2

# %%
woz = pd.read_csv('woz.csv')
woz

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(14,10))
plt.title('ARIMA aapl (Apple, Inc) Model Performance')
sns.lineplot(x='Date',y='value',hue='variable',data=woz)
plt.ylabel('Close')
# Out:
# Text(0, 0.5, 'Close')

# %%
'hello'
# Out:
# 'hello'

# %%
2
# Out:
# 2

# %%
woz
# Out:
#        Unnamed: 0        Date variable       value
# 0               0  1990-12-10        y    1.336600
# 1               1  1990-12-11        y    1.280800
# 2               2  1990-12-12        y    1.267700
# 3               3  1990-12-13        y    1.305000
# 4               4  1990-12-14        y    1.276800
# ...           ...         ...      ...         ...
# 13559       13559  2017-11-06    y_hat  194.540848
# 13560       13560  2017-11-07    y_hat  196.874000
# 13561       13561  2017-11-08    y_hat  198.640564
# 13562       13562  2017-11-09    y_hat  198.058084
# 13563       13563  2017-11-10    y_hat  199.048721
#
# [13564 rows x 4 columns]

# %%
woz.drop('Unnamed: 0',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cc995e15fad2> in <module>
# ----> 1 woz.drop('Unnamed: 0',axis=1,inplace=True)
#
# NameError: name 'woz' is not defined

# %%
iphone = pd.pivot()
